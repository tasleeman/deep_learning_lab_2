# %% [markdown]
# **Name** : Tasleem Anis <br>
# **Roll Number** : 69 <br>
# **Batch** : D4 <br>
# **Date** : 19-01-2024  <br>
# **Practical** : 02(A) <br>

# %%
x_input = [0.1,0.5,0.2]
w_weight = [0.4,0.3,0.6] 
threshold = 0.2

# %%
def step (weighted_sum): 
  if weighted_sum > threshold:
    return 1
  else:
    return 0

# %%
def perceptron():
  weighted_sum = 0
  for x,w in zip(x_input,w_weight):
    weighted_sum += x*w
    print(weighted_sum)
  return step(weighted_sum)

# %%
output = perceptron()
print("Output =", output)
# Out:
# 0.04000000000000001
# 0.19
# 0.31
# Output = 1

# %%
#learning rate and bias,how to calclate loss and update weight in next lab

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f5069154-2cac-42dd-9e6e-2742416c4eb5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5069154-2cac-42dd-9e6e-2742416c4eb5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['Titanic-Dataset.csv']))

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2.drop(['Cabin'],axis=1,inplace=True)

# %%
df2.Age.mean()
# Out:
# 29.69911764705882

# %%
df2["Age"].fillna(29, inplace = True)

# %%
df2["Age"].replace(29,28.57,inplace = True)

# %%
df2["Age"].astype(int)
# Out:
# 0      22
# 1      38
# 2      26
# 3      35
# 4      35
#        ..
# 886    27
# 887    19
# 888    28
# 889    26
# 890    32
# Name: Age, Length: 891, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df2['Sex'].replace({'female': 1, 'male': 2}, inplace=True)

# %%
df2.drop(['Embarked'],axis=1,inplace=True)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    2  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.00      1
# 2                               Heikkinen, Miss. Laina    1  26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.00      1
# 4                             Allen, Mr. William Henry    2  35.00      0
# ..                                                 ...  ...    ...    ...
# ...

# %%
df2.drop(['Ticket'],axis=1,inplace=True)

# %%
df2.drop(['Fare'],axis=1,inplace=True)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    2  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.00      1
# 2                               Heikkinen, Miss. Laina    1  26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.00      1
# 4                             Allen, Mr. William Henry    2  35.00      0
# ..                                                 ...  ...    ...    ...
# ...

# %%
target = df2.Survived

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    2  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.00      1
# 2                               Heikkinen, Miss. Laina    1  26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.00      1
# 4                             Allen, Mr. William Henry    2  35.00      0
# ..                                                 ...  ...    ...    ...
# ...

# %%
df2.drop(['Survived'],axis=1,inplace=True)

# %%
df2
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
#      Sex    Age  SibSp  Parch
# ...

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df2.drop(['Name'],axis=1,inplace=True)

# %% [markdown]
# Perceptron of sklearn

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df2,target,test_size = 0.3)

# %%
[X_train.shape,
X_test.shape,
y_train.shape,
y_test.shape]
# Out:
# [(623, 6), (268, 6), (623,), (268,)]

# %%
model = Perceptron()
model.fit(X_train,y_train)
y_predict = model.predict(X_test)

print(accuracy_score(y_test,y_predict))
# Out:
# 0.5671641791044776

# %%
df2.drop(['PassengerId'],axis=1,inplace=True)
df2.drop(['SibSp'],axis=1,inplace=True)
df2.drop(['Parch'],axis=1,inplace=True)

# %%
df2
# Out:
#      Pclass  Sex    Age
# 0         3    2  22.00
# 1         1    1  38.00
# 2         3    1  26.00
# 3         1    1  35.00
# 4         3    2  35.00
# ..      ...  ...    ...
# 886       2    2  27.00
# 887       1    1  19.00
# 888       3    1  28.57
# 889       1    2  26.00
# 890       3    2  32.00
#
# [891 rows x 3 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Sex     891 non-null    int64
#  2   Age     891 non-null    float64
# dtypes: float64(1), int64(2)
# memory usage: 21.0 KB

# %%
[X_train.shape,
X_test.shape,
y_train.shape,
y_test.shape]
# Out:
# [(623, 6), (268, 6), (623,), (268,)]

# %%
# Approach :::::::::::::::::::::::::::::::::
#1. Initialization - weight,learning_rate,epoc,bias
#2. fit/train : z=dot[x weight] + bias
#y_pred = activation(z)
#wt += learning_rate * (y-y_pred)*x
# b += learning_rate*(y-y_pred)
# Activation,predict,classification Report functions

# %%
import numpy as np

class pracperceptron:
  def __init__(self,learning_rate,epochs):
    self.weights = None
    self.bias = None
    self.learning_rate = learning_rate
    self.epochs = epochs

  def activation(self, z):
    return np.heaviside(z,0)

  def fit(self,X,y):
    n_samples,n_features = X.shape
    self.weights = np.zeros(n_features)
    self.bias = 0

    for epoch in range(self.epochs):
      for i in range(n_samples):
        z = np.dot(X.iloc[i],self.weights) + self.bias
        y_pred = self.activation(z)

        self.weights += self.learning_rate*(y.iloc[i]-y_pred)*X.iloc[i]
        self.bias += self.learning_rate*(y.iloc[i]-y_pred)
  def predict(self, X):
    z = np.dot(X,self.weights) + self.bias
    return self.activation(z)

# %%
perceptron = Perceptron(0.01, 10)
perceptron.fit(X_train, y_train)
pred = perceptron.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.5932835820895522

# %%
#MY CELL
perceptron = pracperceptron(0.01,10)
perceptron.fit(X_train,y_train)

pred = perceptron.predict(X_test)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_predict))
# Out:
# 0.5783582089552238

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Sex     891 non-null    int64
#  2   Age     891 non-null    float64
# dtypes: float64(1), int64(2)
# memory usage: 21.0 KB

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test,pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.55      0.67       157
#            1       0.57      0.86      0.69       111
#
#     accuracy                           0.68       268
#    macro avg       0.71      0.71      0.68       268
# weighted avg       0.74      0.68      0.68       268

# %%
# Define the hyperparameter grid
parame_grid = {'alpha': [0.0001, 0.001, 0.01, 0.1, 1.0],
'max_iter': [10, 50, 100, 200, 500]}

# %%
from sklearn.linear_model import Perceptron

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score

grid_search = GridSearchCV(cv=5, estimator=Perceptron(),
param_grid= parame_grid,
scoring='accuracy')

# %%
grid_search.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_stochastic_gradient.py:702: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_stochastic_gradient.py:702: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_stochastic_gradient.py:702: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_stochastic_gradient.py:702: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# ...

# %%
# Get the best parameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'alpha': 0.0001, 'max_iter': 50}

# %%
# Initialize the perceptron with the best parameters
best_perceptron = pracperceptron(best_params['alpha'],best_params['max_iter'])

# Train the perceptron
best_perceptron.fit(X_train, y_train)

# Make predictions on the test set
y_pred = best_perceptron.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.5970149253731343
